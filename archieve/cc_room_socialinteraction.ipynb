# %%
import numpy as np
import scipy as sc
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import math
from scipy.io import loadmat
from scipy import signal
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
t_r_lhw_m = np.transpose(loadmat('central/temperature_room_male_lhw_central.mat')['temperature_room_male_lhw_central'][0])
t_r_lhw_f = np.transpose(loadmat('central/temperature_room_female_lhw_central.mat')['temperature_room_female_lhw_central'][0])
h_r_lhw_m = np.transpose(loadmat('central/humidity_room_male_lhw_central.mat')['humidity_room_male_lhw_central'][0])
h_r_lhw_f = np.transpose(loadmat('central/humidity_room_female_lhw_central.mat')['humidity_room_female_lhw_central'][0])
t_r_lhw_m = (t_r_lhw_m - np.nanmean(t_r_lhw_m))/np.nanstd(t_r_lhw_m)
t_r_lhw_f = (t_r_lhw_f - np.nanmean(t_r_lhw_f))/np.nanstd(t_r_lhw_f)
h_r_lhw_m = (h_r_lhw_m - np.nanmean(h_r_lhw_m))/np.nanstd(h_r_lhw_m)
h_r_lhw_f = (h_r_lhw_f - np.nanmean(h_r_lhw_f))/np.nanstd(h_r_lhw_f)

t_r_le_m = np.transpose(loadmat('central/temperature_room_male_le_central.mat')['temperature_room_male_le_central'][0])
t_r_le_f = np.transpose(loadmat('central/temperature_room_female_le_central.mat')['temperature_room_female_le_central'][0])
h_r_le_m = np.transpose(loadmat('central/humidity_room_male_le_central.mat')['humidity_room_male_le_central'][0])
h_r_le_f = np.transpose(loadmat('central/humidity_room_female_le_central.mat')['humidity_room_female_le_central'][0])
t_r_le_m = (t_r_le_m - np.nanmean(t_r_le_m))/np.nanstd(t_r_le_m)
t_r_le_f = (t_r_le_f - np.nanmean(t_r_le_f))/np.nanstd(t_r_le_f)
h_r_le_m = (h_r_le_m - np.nanmean(h_r_le_m))/np.nanstd(h_r_le_m)
h_r_le_f = (h_r_le_f - np.nanmean(h_r_le_f))/np.nanstd(h_r_le_f)


t_r_sd_m = pickle.load(open('central/m_room_temp_central_full_ed2_hour','rb'))
t_r_sd_f = pickle.load(open('central/f_room_temp_central_full_ed2_hour','rb'))
h_r_sd_m = pickle.load(open('central/m_room_hum_central_full_ed2_hour','rb'))
h_r_sd_f = pickle.load(open('central/f_room_hum_central_full_ed2_hour','rb'))
t_r_sd_m = (t_r_sd_m - np.nanmean(t_r_sd_m))/np.nanstd(t_r_sd_m)
t_r_sd_f = (t_r_sd_f - np.nanmean(t_r_sd_f))/np.nanstd(t_r_sd_f)
h_r_sd_m = (h_r_sd_m - np.nanmean(h_r_sd_m))/np.nanstd(h_r_sd_m)
h_r_sd_f = (h_r_sd_f - np.nanmean(h_r_sd_f))/np.nanstd(h_r_sd_f)

# %%
t_a_lh_m = np.transpose(loadmat('measures/temperature_male_listerhooded_overall_h_regular_mean.mat')['temperature_male_listerhooded_overall_h_regular_mean'][0])
t_a_le_m = np.transpose(loadmat('measures/temperature_male_longevans_overall_h_regular_mean.mat')['temperature_male_longevans_overall_h_regular_mean'][0])
t_a_sd_m = np.transpose(loadmat('measures/temperature_male_spraguedawley_overall_h_regular_mean.mat')['temperature_male_spraguedawley_overall_h_regular_mean'][0])
t_a_w_m = np.transpose(loadmat('measures/temperature_male_wistar_overall_h_regular_mean.mat')['temperature_male_wistar_overall_h_regular_mean'][0])

t_a_lh_m = (t_a_lh_m - np.nanmean(t_a_lh_m))/np.nanstd(t_a_lh_m)
t_a_le_m = (t_a_le_m - np.nanmean(t_a_le_m))/np.nanstd(t_a_le_m)
t_a_sd_m = (t_a_sd_m - np.nanmean(t_a_sd_m))/np.nanstd(t_a_sd_m)
t_a_w_m = (t_a_w_m - np.nanmean(t_a_w_m))/np.nanstd(t_a_w_m)



di_a_lh_m = np.transpose(loadmat('measures/distance_male_listerhooded_overall_h_regular_mean.mat')['distance_male_listerhooded_overall_h_regular_mean'][0])
di_a_le_m = np.transpose(loadmat('measures/distance_male_longevans_overall_h_regular_mean.mat')['distance_male_longevans_overall_h_regular_mean'][0])
di_a_sd_m = np.transpose(loadmat('measures/distance_male_spraguedawley_overall_h_regular_mean.mat')['distance_male_spraguedawley_overall_h_regular_mean'][0])
di_a_w_m = np.transpose(loadmat('measures/distance_male_wistar_overall_h_regular_mean.mat')['distance_male_wistar_overall_h_regular_mean'][0])

di_a_lh_m = (di_a_lh_m - np.nanmean(di_a_lh_m))/np.nanstd(di_a_lh_m)
di_a_le_m = (di_a_le_m - np.nanmean(di_a_le_m))/np.nanstd(di_a_le_m)
di_a_sd_m = (di_a_sd_m - np.nanmean(di_a_sd_m))/np.nanstd(di_a_sd_m)
di_a_w_m = (di_a_w_m - np.nanmean(di_a_w_m))/np.nanstd(di_a_w_m) 



dr_a_lh_m = np.transpose(loadmat('measures/drinking_male_listerhooded_overall_h_regular_mean.mat')['drinking_male_listerhooded_overall_h_regular_mean'][0])
dr_a_le_m = np.transpose(loadmat('measures/drinking_male_longevans_overall_h_regular_mean.mat')['drinking_male_longevans_overall_h_regular_mean'][0])
dr_a_sd_m = np.transpose(loadmat('measures/drinking_male_spraguedawley_overall_h_regular_mean.mat')['drinking_male_spraguedawley_overall_h_regular_mean'][0])
dr_a_w_m = np.transpose(loadmat('measures/drinking_male_wistar_overall_h_regular_mean.mat')['drinking_male_wistar_overall_h_regular_mean'][0])

dr_a_lh_m = (dr_a_lh_m - np.nanmean(dr_a_lh_m))/np.nanstd(dr_a_lh_m)
dr_a_le_m = (dr_a_le_m - np.nanmean(dr_a_le_m))/np.nanstd(dr_a_le_m)
dr_a_sd_m = (dr_a_sd_m - np.nanmean(dr_a_sd_m))/np.nanstd(dr_a_sd_m)
dr_a_w_m = (dr_a_w_m - np.nanmean(dr_a_w_m))/np.nanstd(dr_a_w_m) 




si_a_lh_m = np.transpose(loadmat('measures/socialinteraction_male_listerhooded_h_regular_mean.mat')['socialinteraction_male_listerhooded_h_regular_mean'][0])
si_a_le_m = np.transpose(loadmat('measures/socialinteraction_male_longevans_h_regular_mean.mat')['socialinteraction_male_longevans_h_regular_mean'][0])
si_a_sd_m = np.transpose(loadmat('measures/socialinteraction_male_spraguedawley_h_regular_mean.mat')['socialinteraction_male_spraguedawley_h_regular_mean'][0])
si_a_w_m = np.transpose(loadmat('measures/socialinteraction_male_wistar_h_regular_mean.mat')['socialinteraction_male_wistar_h_regular_mean'][0])

si_a_lh_m = (si_a_lh_m - np.nanmean(si_a_lh_m))/np.nanstd(si_a_lh_m)
si_a_le_m = (si_a_le_m - np.nanmean(si_a_le_m))/np.nanstd(si_a_le_m)
si_a_sd_m = (si_a_sd_m - np.nanmean(si_a_sd_m))/np.nanstd(si_a_sd_m)
si_a_w_m = (si_a_w_m - np.nanmean(si_a_w_m))/np.nanstd(si_a_w_m) 




v_a_lh_m = np.transpose(loadmat('measures/velocity_male_listerhooded_h_regular_mean.mat')['velocity_male_listerhooded_h_regular_mean'][0])
v_a_le_m = np.transpose(loadmat('measures/velocity_male_longevans_h_regular_mean.mat')['velocity_male_longevans_h_regular_mean'][0])
v_a_sd_m = np.transpose(loadmat('measures/velocity_male_spraguedawley_h_regular_mean.mat')['velocity_male_spraguedawley_h_regular_mean'][0])
v_a_w_m = np.transpose(loadmat('measures/velocity_male_wistar_h_regular_mean.mat')['velocity_male_wistar_h_regular_mean'][0])

v_a_lh_m = (v_a_lh_m - np.nanmean(v_a_lh_m))/np.nanstd(v_a_lh_m)
v_a_le_m = (v_a_le_m - np.nanmean(v_a_le_m))/np.nanstd(v_a_le_m)
v_a_sd_m = (v_a_sd_m - np.nanmean(v_a_sd_m))/np.nanstd(v_a_sd_m)
v_a_w_m = (v_a_w_m - np.nanmean(v_a_w_m))/np.nanstd(v_a_w_m)

# %%
t_a_lh_f = np.transpose(loadmat('measures/temperature_female_listerhooded_overall_h_regular_mean.mat')['temperature_female_listerhooded_overall_h_regular_mean'][0])
t_a_le_f = np.transpose(loadmat('measures/temperature_female_longevans_overall_h_regular_mean.mat')['temperature_female_longevans_overall_h_regular_mean'][0])
t_a_sd_f = np.transpose(loadmat('measures/temperature_female_spraguedawley_overall_h_regular_mean.mat')['temperature_female_spraguedawley_overall_h_regular_mean'][0])
t_a_w_f = np.transpose(loadmat('measures/temperature_female_wistar_overall_h_regular_mean.mat')['temperature_female_wistar_overall_h_regular_mean'][0])

t_a_lh_f = (t_a_lh_f - np.nanmean(t_a_lh_f))/np.nanstd(t_a_lh_f)
t_a_le_f = (t_a_le_f - np.nanmean(t_a_le_f))/np.nanstd(t_a_le_f)
t_a_sd_f = (t_a_sd_f - np.nanmean(t_a_sd_f))/np.nanstd(t_a_sd_f)
t_a_w_f = (t_a_w_f - np.nanmean(t_a_w_f))/np.nanstd(t_a_w_f)



di_a_lh_f = np.transpose(loadmat('measures/distance_female_listerhooded_overall_h_regular_mean.mat')['distance_female_listerhooded_overall_h_regular_mean'][0])
di_a_le_f = np.transpose(loadmat('measures/distance_female_longevans_overall_h_regular_mean.mat')['distance_female_longevans_overall_h_regular_mean'][0])
di_a_sd_f = np.transpose(loadmat('measures/distance_female_spraguedawley_overall_h_regular_mean.mat')['distance_female_spraguedawley_overall_h_regular_mean'][0])
di_a_w_f = np.transpose(loadmat('measures/distance_female_wistar_overall_h_regular_mean.mat')['distance_female_wistar_overall_h_regular_mean'][0])

di_a_lh_f = (di_a_lh_f - np.nanmean(di_a_lh_f))/np.nanstd(di_a_lh_f)
di_a_le_f = (di_a_le_f - np.nanmean(di_a_le_f))/np.nanstd(di_a_le_f)
di_a_sd_f = (di_a_sd_f - np.nanmean(di_a_sd_f))/np.nanstd(di_a_sd_f)
di_a_w_f = (di_a_w_f - np.nanmean(di_a_w_f))/np.nanstd(di_a_w_f) 



dr_a_lh_f = np.transpose(loadmat('measures/drinking_female_listerhooded_overall_h_regular_mean.mat')['drinking_female_listerhooded_overall_h_regular_mean'][0])
dr_a_le_f = np.transpose(loadmat('measures/drinking_female_longevans_overall_h_regular_mean.mat')['drinking_female_longevans_overall_h_regular_mean'][0])
dr_a_sd_f = np.transpose(loadmat('measures/drinking_female_spraguedawley_overall_h_regular_mean.mat')['drinking_female_spraguedawley_overall_h_regular_mean'][0])
dr_a_w_f = np.transpose(loadmat('measures/drinking_female_wistar_overall_h_regular_mean.mat')['drinking_female_wistar_overall_h_regular_mean'][0])

dr_a_lh_f = (dr_a_lh_f - np.nanmean(dr_a_lh_f))/np.nanstd(dr_a_lh_f)
dr_a_le_f = (dr_a_le_f - np.nanmean(dr_a_le_f))/np.nanstd(dr_a_le_f)
dr_a_sd_f = (dr_a_sd_f - np.nanmean(dr_a_sd_f))/np.nanstd(dr_a_sd_f)
dr_a_w_f = (dr_a_w_f - np.nanmean(dr_a_w_f))/np.nanstd(dr_a_w_f) 




si_a_lh_f = np.transpose(loadmat('measures/socialinteraction_female_listerhooded_h_regular_mean.mat')['socialinteraction_female_listerhooded_h_regular_mean'][0])
si_a_le_f = np.transpose(loadmat('measures/socialinteraction_female_longevans_h_regular_mean.mat')['socialinteraction_female_longevans_h_regular_mean'][0])
si_a_sd_f = np.transpose(loadmat('measures/socialinteraction_female_spraguedawley_h_regular_mean.mat')['socialinteraction_female_spraguedawley_h_regular_mean'][0])
si_a_w_f = np.transpose(loadmat('measures/socialinteraction_female_wistar_h_regular_mean.mat')['socialinteraction_female_wistar_h_regular_mean'][0])

si_a_lh_f = (si_a_lh_f - np.nanmean(si_a_lh_f))/np.nanstd(si_a_lh_f)
si_a_le_f = (si_a_le_f - np.nanmean(si_a_le_f))/np.nanstd(si_a_le_f)
si_a_sd_f = (si_a_sd_f - np.nanmean(si_a_sd_f))/np.nanstd(si_a_sd_f)
si_a_w_f = (si_a_w_f - np.nanmean(si_a_w_f))/np.nanstd(si_a_w_f) 




v_a_lh_f = np.transpose(loadmat('measures/velocity_female_listerhooded_h_regular_mean.mat')['velocity_female_listerhooded_h_regular_mean'][0])
v_a_le_f = np.transpose(loadmat('measures/velocity_female_longevans_h_regular_mean.mat')['velocity_female_longevans_h_regular_mean'][0])
v_a_sd_f = np.transpose(loadmat('measures/velocity_female_spraguedawley_h_regular_mean.mat')['velocity_female_spraguedawley_h_regular_mean'][0])
v_a_w_f = np.transpose(loadmat('measures/velocity_female_wistar_h_regular_mean.mat')['velocity_female_wistar_h_regular_mean'][0])

v_a_lh_f = (v_a_lh_f - np.nanmean(v_a_lh_f))/np.nanstd(v_a_lh_f)
v_a_le_f = (v_a_le_f - np.nanmean(v_a_le_f))/np.nanstd(v_a_le_f)
v_a_sd_f = (v_a_sd_f - np.nanmean(v_a_sd_f))/np.nanstd(v_a_sd_f)
v_a_w_f = (v_a_w_f - np.nanmean(v_a_w_f))/np.nanstd(v_a_w_f)

# %%
df_lh_m = pd.DataFrame({'animal_temperature': t_a_lh_m,'animal_distance' : di_a_lh_m ,
                   'animal_drinking' : dr_a_lh_m ,'animal_socialinteraction' : si_a_lh_m,
                      'animal_velocity' : v_a_lh_m, 'room_temperature': t_r_lhw_m, 'room_humidity':h_r_lhw_m})

df_lh_f = pd.DataFrame({'animal_temperature': t_a_lh_f,'animal_distance' : di_a_lh_f ,
                   'animal_drinking' : dr_a_lh_f ,'animal_socialinteraction' : si_a_lh_f,
                      'animal_velocity' : v_a_lh_f, 'room_temperature': t_r_lhw_f, 'room_humidity':h_r_lhw_f})

df_le_m = pd.DataFrame({'animal_temperature': t_a_le_m,'animal_distance' : di_a_le_m ,
                   'animal_drinking' : dr_a_le_m ,'animal_socialinteraction' : si_a_le_m,
                      'animal_velocity' : v_a_le_m, 'room_temperature': t_r_le_m, 'room_humidity':h_r_le_m})

df_le_f = pd.DataFrame({'animal_temperature': t_a_le_f,'animal_distance' : di_a_le_f ,
                   'animal_drinking' : dr_a_le_f ,'animal_socialinteraction' : si_a_le_f,
                      'animal_velocity' : v_a_le_f, 'room_temperature': t_r_le_f, 'room_humidity':h_r_le_f})

df_sd_m = pd.DataFrame({'animal_temperature': t_a_sd_m,'animal_distance' : di_a_sd_m ,
                   'animal_drinking' : dr_a_sd_m ,'animal_socialinteraction' : si_a_sd_m,
                      'animal_velocity' : v_a_sd_m, 'room_temperature': t_r_sd_m, 'room_humidity':h_r_sd_m})

df_sd_f = pd.DataFrame({'animal_temperature': t_a_sd_f,'animal_distance' : di_a_sd_f ,
                   'animal_drinking' : dr_a_sd_f ,'animal_socialinteraction' : si_a_sd_f,
                      'animal_velocity' : v_a_sd_f, 'room_temperature': t_r_sd_f, 'room_humidity':h_r_sd_f})

df_w_m = pd.DataFrame({'animal_temperature': t_a_w_m,'animal_distance' : di_a_w_m ,
                   'animal_drinking' : dr_a_w_m ,'animal_socialinteraction' : si_a_w_m,
                      'animal_velocity' : v_a_w_m, 'room_temperature': t_r_lhw_m, 'room_humidity':h_r_lhw_m})

df_w_f = pd.DataFrame({'animal_temperature': t_a_w_f,'animal_distance' : di_a_w_f ,
                   'animal_drinking' : dr_a_w_f ,'animal_socialinteraction' : si_a_w_f,
                      'animal_velocity' : v_a_w_f, 'room_temperature': t_r_lhw_f, 'room_humidity':h_r_lhw_f})

# %%
def crosscorr(datax, datay, lag=0, wrap=False):

    if wrap:
        shiftedy = datay.shift(lag)
        shiftedy.iloc[:lag] = datay.iloc[-lag:].values
        return datax.corr(shiftedy)
    else: 
        return datax.corr(datay.shift(lag))

# Rolling window time lagged cross correlation
seconds = 120
fps = 1
window_size = 120 #samples
t_start = 0
t_end = t_start + window_size
step_size = 12
rss_1=[]
rss_2=[]
rss_3=[]
rss_4=[]
rss_5=[]
rss_6=[]
rss_7=[]
rss_8=[]
rss_9=[]
rss_10=[]
rss_11=[]
rss_12=[]
rss_13=[]
rss_14=[]
rss_15=[]
rss_16=[]

while t_end < 1800:
    d1_1 = df_lh_m['room_temperature'].iloc[t_start:t_end]
    d1_2 = df_lh_m['animal_socialinteraction'].iloc[t_start:t_end]
    d2_1 = df_lh_f['room_temperature'].iloc[t_start:t_end]
    d2_2 = df_lh_f['animal_socialinteraction'].iloc[t_start:t_end]
    d3_1 = df_lh_m['room_humidity'].iloc[t_start:t_end]
    d3_2 = df_lh_m['animal_socialinteraction'].iloc[t_start:t_end]
    d4_1 = df_lh_f['room_humidity'].iloc[t_start:t_end]
    d4_2 = df_lh_f['animal_socialinteraction'].iloc[t_start:t_end]
    
    d5_1 = df_le_m['room_temperature'].iloc[t_start:t_end]
    d5_2 = df_le_m['animal_socialinteraction'].iloc[t_start:t_end]
    d6_1 = df_le_f['room_temperature'].iloc[t_start:t_end]
    d6_2 = df_le_f['animal_socialinteraction'].iloc[t_start:t_end]
    d7_1 = df_le_m['room_humidity'].iloc[t_start:t_end]
    d7_2 = df_le_m['animal_socialinteraction'].iloc[t_start:t_end]
    d8_1 = df_le_f['room_humidity'].iloc[t_start:t_end]
    d8_2 = df_le_f['animal_socialinteraction'].iloc[t_start:t_end] 
    
    d9_1 = df_sd_m['room_temperature'].iloc[t_start:t_end]
    d9_2 = df_sd_m['animal_socialinteraction'].iloc[t_start:t_end]
    d10_1 = df_sd_f['room_temperature'].iloc[t_start:t_end]
    d10_2 = df_sd_f['animal_socialinteraction'].iloc[t_start:t_end]
    d11_1 = df_sd_m['room_humidity'].iloc[t_start:t_end]
    d11_2 = df_sd_m['animal_socialinteraction'].iloc[t_start:t_end]
    d12_1 = df_sd_f['room_humidity'].iloc[t_start:t_end]
    d12_2 = df_sd_f['animal_socialinteraction'].iloc[t_start:t_end]
    
    d13_1 = df_w_m['room_temperature'].iloc[t_start:t_end]
    d13_2 = df_w_m['animal_socialinteraction'].iloc[t_start:t_end]
    d14_1 = df_w_f['room_temperature'].iloc[t_start:t_end]
    d14_2 = df_w_f['animal_socialinteraction'].iloc[t_start:t_end]
    d15_1 = df_w_m['room_humidity'].iloc[t_start:t_end]
    d15_2 = df_w_m['animal_socialinteraction'].iloc[t_start:t_end]
    d16_1 = df_w_f['room_humidity'].iloc[t_start:t_end]
    d16_2 = df_w_f['animal_socialinteraction'].iloc[t_start:t_end]
    
    temp = [crosscorr(d1_1,d1_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_1.append(temp)
    temp = [crosscorr(d2_1,d2_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_2.append(temp)
    temp = [crosscorr(d3_1,d3_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_3.append(temp)
    temp = [crosscorr(d4_1,d4_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_4.append(temp)
    temp = [crosscorr(d5_1,d5_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_5.append(temp)
    temp = [crosscorr(d6_1,d6_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_6.append(temp)
    temp = [crosscorr(d7_1,d7_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_7.append(temp)
    temp = [crosscorr(d8_1,d8_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_8.append(temp)
    temp = [crosscorr(d9_1,d9_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_9.append(temp)
    temp = [crosscorr(d10_1,d10_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_10.append(temp)
    temp = [crosscorr(d11_1,d11_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_11.append(temp)
    temp = [crosscorr(d12_1,d12_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_12.append(temp)
    temp = [crosscorr(d13_1,d13_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_13.append(temp)
    temp = [crosscorr(d14_1,d14_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_14.append(temp)
    temp = [crosscorr(d15_1,d15_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_15.append(temp)
    temp = [crosscorr(d16_1,d16_2, lag, wrap=False) for lag in range(-int(seconds*fps),int(seconds*fps+1))]
    rss_16.append(temp)
    
    t_start = t_start + step_size
    t_end = t_end + step_size
    
    
rss_1 = pd.DataFrame(rss_1)
rss_2 = pd.DataFrame(rss_2)
rss_3 = pd.DataFrame(rss_3)
rss_4 = pd.DataFrame(rss_4)
rss_5 = pd.DataFrame(rss_5)
rss_6 = pd.DataFrame(rss_6)
rss_7 = pd.DataFrame(rss_7)
rss_8 = pd.DataFrame(rss_8)
rss_9 = pd.DataFrame(rss_9)
rss_10 = pd.DataFrame(rss_10)
rss_11 = pd.DataFrame(rss_11)
rss_12 = pd.DataFrame(rss_12)
rss_13 = pd.DataFrame(rss_13)
rss_14 = pd.DataFrame(rss_14)
rss_15 = pd.DataFrame(rss_15)
rss_16 = pd.DataFrame(rss_16)

# %%
import matplotlib as mpl
# Say, "the default sans-serif font is COMIC SANS"
plt.rcParams['font.sans-serif'] = "Arial"
# Then, "ALWAYS use sans-serif fonts"
plt.rcParams['font.family'] = "Arial"
f ,([ax1,ax2,ax3,ax4],[ax5,ax6,ax7,ax8], [ax9,ax10,ax11,ax12],[ax13,ax14,ax15,ax16]) = plt.subplots(4,4, gridspec_kw={'width_ratios':[1,1,1,1]},figsize=(20,20))
ax1.get_shared_y_axes().join(ax2,ax3,ax4)
ax5.get_shared_y_axes().join(ax6,ax7,ax8)
ax9.get_shared_y_axes().join(ax10,ax11,ax12)
ax13.get_shared_y_axes().join(ax14,ax15,ax16)

size = 20
sizee = 25

ticks=np.array([-1,0,+1])
cmap = plt.get_cmap('RdBu_r')
f.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
cax = f.add_axes([0.85, 0.1, 0.075, 0.8])


cb1 = mpl.colorbar.ColorbarBase(cax, cmap=cmap, orientation='vertical',norm=plt.Normalize(ticks[0],ticks[-1]))
cb1.set_ticks(ticks)
cb1.ax.set_yticklabels(ticks)
#cb1.set_ticklabels([-1, 0, 1])
#cb1.set_ticks(ticks)
#cb1.set_ticklabels(['-1', '0', '1'])

g1 = sns.heatmap(rss_1,cmap=cmap,cbar=False,ax=ax1)
g1.set_ylabel('')
g1.set_xlabel('')
g1.set_xticks([])
g2 = sns.heatmap(rss_2,cmap=cmap,cbar=False,ax=ax2)
g2.set_ylabel('')
g2.set_xlabel('')
g2.set_yticks([])
g2.set_xticks([])
g3 = sns.heatmap(rss_3,cmap=cmap,cbar=False,ax=ax3)
g3.set_ylabel('')
g3.set_xlabel('')
g3.set_yticks([])
g3.set_xticks([])
g4 = sns.heatmap(rss_4,cmap=cmap,cbar=False,ax=ax4)
g4.set_ylabel('')
g4.set_xlabel('')
g4.set_yticks([])
g4.set_xticks([])

g5 = sns.heatmap(rss_5,cmap=cmap,cbar=False,ax=ax5)
g5.set_ylabel('')
g5.set_xlabel('')
g5.set_xticks([])
g6 = sns.heatmap(rss_6,cmap=cmap,cbar=False,ax=ax6)
g6.set_ylabel('')
g6.set_xlabel('')
g6.set_yticks([])
g6.set_xticks([])
g7 = sns.heatmap(rss_7,cmap=cmap,cbar=False,ax=ax7)
g7.set_ylabel('')
g7.set_xlabel('')
g7.set_yticks([])
g7.set_xticks([])
g8 = sns.heatmap(rss_8,cmap=cmap,cbar=False,ax=ax8)
g8.set_ylabel('')
g8.set_xlabel('')
g8.set_yticks([])
g8.set_xticks([])

g9 = sns.heatmap(rss_9,cmap=cmap,cbar=False,ax=ax9)
g9.set_ylabel('')
g9.set_xlabel('')
g9.set_xticks([])
g10 = sns.heatmap(rss_10,cmap=cmap,cbar=False,ax=ax10)
g10.set_ylabel('')
g10.set_xlabel('')
g10.set_yticks([])
g10.set_xticks([])
g11 = sns.heatmap(rss_11,cmap=cmap,cbar=False,ax=ax11)
g11.set_ylabel('')
g11.set_xlabel('')
g11.set_yticks([])
g11.set_xticks([])
g12 = sns.heatmap(rss_12,cmap=cmap,cbar=False,ax=ax12)
g12.set_ylabel('')
g12.set_xlabel('')
g12.set_yticks([])
g12.set_xticks([])

g13 = sns.heatmap(rss_13,cmap=cmap,cbar=False,ax=ax13)
g13.set_ylabel('')
g13.set_xlabel('')
g13.set_xticks([])
g14 = sns.heatmap(rss_14,cmap=cmap,cbar=False,ax=ax14)
g14.set_ylabel('')
g14.set_xlabel('')
g14.set_yticks([])
g14.set_xticks([])
g15 = sns.heatmap(rss_15,cmap=cmap,cbar=False,ax=ax15)
g15.set_ylabel('')
g15.set_xlabel('')
g15.set_yticks([])
g15.set_xticks([])
g16 = sns.heatmap(rss_16,cmap=cmap,cbar=False,ax=ax16)
g16.set_ylabel('')
g16.set_xlabel('')
g16.set_yticks([])
g16.set_xticks([])



cax = plt.gcf().axes[-1]
cax.tick_params(labelsize=size)
g13.set_xticks([0,40, 80, 120,160,200, 240])
g13.set_xticklabels([-120, -80, -40, 0, 40, 80, 120]);
g14.set_xticks([0,40, 80, 120,160,200, 240])
g14.set_xticklabels([-120, -80, -40, 0, 40, 80, 120]);
g15.set_xticks([0,40, 80, 120,160,200, 240])
g15.set_xticklabels([-120, -80, -40, 0, 40, 80, 120]);
g16.set_xticks([0,40, 80, 120,160,200, 240])
g16.set_xticklabels([-120, -80, -40, 0, 40, 80, 120]);

g1.set_yticks([0, 20, 40, 60, 80, 100, 120, 140])
g1.set_yticklabels([0, 20, 40, 60, 80, 100, 120, 140]);
g5.set_yticks([0, 20, 40, 60, 80, 100, 120, 140])
g5.set_yticklabels([0, 20, 40, 60, 80, 100, 120, 140]);
g9.set_yticks([0, 20, 40, 60, 80, 100, 120, 140])
g9.set_yticklabels([0, 20, 40, 60, 80, 100, 120, 140]);
g13.set_yticks([0, 20, 40, 60, 80, 100, 120, 140])
g13.set_yticklabels([0, 20, 40, 60, 80, 100, 120, 140]);



g1.tick_params(axis ='both',which = 'both',labelsize=size)
g2.tick_params(axis ='both',which = 'both',labelsize=size)
g3.tick_params(axis ='both',which = 'both',labelsize=size)
g4.tick_params(axis ='both',which = 'both',labelsize=size)
g5.tick_params(axis ='both',which = 'both',labelsize=size)
g6.tick_params(axis ='both',which = 'both',labelsize=size)
g7.tick_params(axis ='both',which = 'both',labelsize=size)
g8.tick_params(axis ='both',which = 'both',labelsize=size)
g9.tick_params(axis ='both',which = 'both',labelsize=size)
g10.tick_params(axis ='both',which = 'both',labelsize=size)
g11.tick_params(axis ='both',which = 'both',labelsize=size)
g12.tick_params(axis ='both',which = 'both',labelsize=size)
g13.tick_params(axis ='both',which = 'both',labelsize=size)
g14.tick_params(axis ='both',which = 'both',labelsize=size)
g15.tick_params(axis ='both',which = 'both',labelsize=size)
g16.tick_params(axis ='both',which = 'both',labelsize=size)


f.text(0.5, 0.04, 'Offset', ha='center', fontsize = sizee+10)
f.text(0.04, 0.5, 'Window', va='center', rotation='vertical', fontsize = sizee+10)

ax1.text(-0.05, 1.15, 'A', transform=ax1.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax2.text(-0.05, 1.15, 'B', transform=ax2.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax3.text(-0.05, 1.15, 'C', transform=ax3.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax4.text(-0.05, 1.15, 'D', transform=ax4.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax5.text(-0.05, 1.15, 'E', transform=ax5.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax6.text(-0.05, 1.15, 'F', transform=ax6.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax7.text(-0.05, 1.15, 'G', transform=ax7.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax8.text(-0.05, 1.15, 'H', transform=ax8.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax9.text(-0.05, 1.15, 'I', transform=ax9.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax10.text(-0.05, 1.15, 'J', transform=ax10.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax11.text(-0.05, 1.15, 'K', transform=ax11.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax12.text(-0.05, 1.15, 'L', transform=ax12.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax13.text(-0.05, 1.15, 'M', transform=ax13.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax14.text(-0.05, 1.15, 'N', transform=ax14.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax15.text(-0.05, 1.15, 'O', transform=ax15.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
ax16.text(-0.05, 1.15, 'P', transform=ax16.transAxes,
      fontsize=sizee, fontweight='bold', va='top', ha='right')
# may be needed to rotate the ticklabels correctly:
for ax in [g1,g2,g3,g4,g5,g6,g7,g8,g9,g10,g11,g12,g13,g14,g15,g16]:
    tl = ax.get_xticklabels()
    ax.set_xticklabels(tl, rotation=45)
    tly = ax.get_yticklabels()
    ax.set_yticklabels(tly, rotation=0)
    
plt.savefig("rwtlcc_room_socialinteraction.jpg", bbox_inches='tight' , dpi = 900)
